# %%
import pandas as pd
import numpy as np
from scipy import sparse
import matplotlib.pyplot as plt
import basicMCMC

# %%
df = basicMCMC.readCSV()
graph = basicMCMC.buildAttackGraph(df)
attackPR = basicMCMC.pagerank(graph)

# %%
attackPR
# Out:
# array([0.0238685 , 0.05422564, 0.04692921, 0.02235459, 0.09214996,
#        0.06710879, 0.07387665, 0.05600747, 0.06500097, 0.0536509 ,
#        0.07907376, 0.05661636, 0.08747568, 0.0340825 , 0.03928258,
#        0.05360596, 0.04642334, 0.04826714])

# %%
def createDict(pr):
    types = ['Normal','Fire','Water','Electric','Grass','Ice',
        'Fighting','Poison','Ground','Flying','Psychic','Bug',
        'Rock','Ghost','Dragon','Dark','Steel','Fairy']
    
    prDict = {}
    for i, type in enumerate(types):
        prDict[type] = pr[i]
    return prDict

attack = createDict(attackPR)

# %%
def plot(prDict):
    plt.figure(figsize=(20,10))
    plt.bar(np.arange(18), prDict.values(), align='center', alpha=1.0)
    plt.xticks(np.arange(18), prDict.keys())
    plt.ylabel('PR Probability')
    plt.xlabel('Pokemon Type')
    plt.title('Pokemon Type PR')
    plt.show()

# %%
plot(attack)

# %%
sortedAttack = sorted(attack.items(), key=lambda x: x[1])
plot(sortedAttack)
# Out:
# -----------------------------------------------------
# AttributeError      Traceback (most recent call last)
# <ipython-input-22-6f74f58da984> in <module>()
#       1 sortedAttack = sorted(attack.items(), key=lambda x: x[1])
# ----> 2 plot(sortedAttack)
#
# <ipython-input-20-1afa71806b9a> in plot(prDict)
#       1 def plot(prDict):
#       2     plt.figure(figsize=(20,10))
# ----> 3     plt.bar(np.arange(18), prDict.values(), align='center', alpha=1.0)
#       4     plt.xticks(np.arange(18), prDict.keys())
#       5     plt.ylabel('PR Probability')
#
# AttributeError: 'list' object has no attribute 'values'
